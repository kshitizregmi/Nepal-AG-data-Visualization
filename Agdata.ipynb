# %%
import pandas as pd

# %%
df = pd.read_excel('D:/agdata/ag.xlsx',sheet_name="Coffee",skipfooter=3)

# %%
df
# Out:
#    Table 2.8:  Coffee: Area, Production and Yield by Districts *, Fiscal Year 2017/18  \
# 0                                                 NaN
# 1                                                 S.N
# 2                                                   1
# 3                                                   2
# 4                                                   3
# 5                                                   4
# 6                                                   5
# 7                                                   6
# 8                                                   7
# 9                                                   8
# 10                                                  9
# 11                                                 10
# 12                                                 11
# 13                                                 12
# 14                                                 13
# 15                                                 14
# ...

# %%
title = "".join(df.columns[:1])[12:]
print(title)
# Out:
# Coffee: Area, Production and Yield by Districts *, Fiscal Year 2017/18

# %%
df.columns = list(df.iloc[1])

# %%
df.head()
# Out:
#    S.N    Districts  Total   Plantation (Ha)  Production (MT) Green Bean  \
# 0  NaN          NaN                      NaN                         NaN
# 1  S.N    Districts  Total   Plantation (Ha)  Production (MT) Green Bean
# 2    1  Arghakhachi                   134.64                          30
# 3    2      Baglung                    64.26                          15
# 4    3      Bhojpur                    16.32                        2.04
#
#    Yield\n(Kg/ha)  Farming \nHouseholds  Remarks
# 0             NaN                   NaN      NaN
# 1  Yield\n(Kg/ha)  Farming \nHouseholds  Remarks
# 2         222.816                  1662      NaN
# 3         233.427                  1345      NaN
# 4             125                166.26      NaN

# %%
# df.pop('Remarks')
# df.pop('S.N')
df.drop(columns=['Remarks', 'S.N'],inplace = True)

# %%
df.head()
# Out:
#      Districts  Total   Plantation (Ha)  Production (MT) Green Bean  \
# 0          NaN                      NaN                         NaN
# 1    Districts  Total   Plantation (Ha)  Production (MT) Green Bean
# 2  Arghakhachi                   134.64                          30
# 3      Baglung                    64.26                          15
# 4      Bhojpur                    16.32                        2.04
#
#    Yield\n(Kg/ha)  Farming \nHouseholds
# 0             NaN                   NaN
# 1  Yield\n(Kg/ha)  Farming \nHouseholds
# 2         222.816                  1662
# 3         233.427                  1345
# 4             125                166.26

# %%
df.drop([0,1], inplace =True)

# %%
df
# Out:
#             Districts Total   Plantation (Ha) Production (MT) Green Bean  \
# 2         Arghakhachi                  134.64                         30
# 3             Baglung                   64.26                         15
# 4             Bhojpur                   16.32                       2.04
# 5            Dhankuta                      26                          3
# 6             Dhading                   74.46                      12.24
# 7              Gorkha                      55                          8
# 8               Gulmi                   163.2                       35.7
# 9                Ilam                    61.2                       15.3
# 10              Kaski                  148.92                         35
# 11              Kavre                  196.86                         30
# 12            Khotang                   21.42                       4.08
# 13           Lalitpur                   132.6                         25
# ...

# %%
district = list(df.Districts)

# %%
df.columns
# Out:
# Index(['Districts', 'Total   Plantation (Ha)', 'Production (MT) Green Bean',
#        'Yield\n(Kg/ha)', 'Farming \nHouseholds'],
#       dtype='object')

# %%
# total = list(df['Total   Plantation (Ha)'])
# production =list(df['Production (MT) Green Bean'])
# yields = list(df['Yield\n(Kg/ha)'])
# houses = list(df['Farming \nHouseholds'])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(300,300))
df.plot.area() 
plt.show()

# %%
#Production (MT) Green Bean
fig1, ax1 = plt.subplots(figsize=(20,20))
ax1.pie(list(df['Production (MT) Green Bean']),labels=list(df.Districts),startangle=90 ,autopct='%1.1f%%' , shadow=True)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# 'Total   Plantation (Ha)'

# %%
fig1, ax1 = plt.subplots(figsize=(20,20))
ax1.pie(list(df['Total   Plantation (Ha)']),labels=list(df.Districts),startangle=90 ,autopct='%1.1f%%' , shadow=True)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
df['Total   Plantation (Ha)'].value_counts().plot(kind='bar')

# %%
df['Production (MT) Green Bean'].value_counts().plot(kind='bar')

# %%
plt.scatter(df['Production (MT) Green Bean'],df['Total   Plantation (Ha)'])
plt.xlabel("Production (MT) Green Bean")
plt.ylabel("Total   Plantation (Ha)")
# Out:
# Text(0, 0.5, 'Total   Plantation (Ha)')

# %%
import seaborn as sns

# %%
sns.catplot(data=df, orient="v", kind="box")

# %% [markdown]
# # total = list(df['Total   Plantation (Ha)'])
# # production =list(df['Production (MT) Green Bean'])
# # yields = list(df['Yield\n(Kg/ha)'])
# # houses = list(df['Farming \nHouseholds'])
